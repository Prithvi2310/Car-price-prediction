# %% [markdown]
# #### Importing libraries and dataset

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = pd.read_csv("Data/CarPrice_Assignment.csv")

# %% [markdown]
# #### Exploring the dataset

# %%
cars.shape
# Out:
# (205, 26)

# %%
pd.set_option('display.max_columns',None)
cars.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
# ...

# %% [markdown]
# The "set_option" method makes pandas change the display settings of DataFrame(and more). So the above command displays all the columns present in the DataFrame instead of truncating it.
#
# If you pass a number instead of "None" then it will allow you to limit the number of columns to be displayed.

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#Checks if any values in the dataset has NaN
cars.isnull().values.any()
# Out:
# False

# %%
cars.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# #### Data Cleaning and Preprocessing

# %% [markdown]
# Pandas.apply allows the users to pass a function and apply it on every single value of the Pandas series.

# %%
CompanyName = cars["CarName"].apply(lambda x : x.split(' ')[0])

# %%
CompanyName.head()
# Out:
# 0    alfa-romero
# 1    alfa-romero
# 2    alfa-romero
# 3           audi
# 4           audi
# Name: CarName, dtype: object

# %%
cars.insert(3,"CompanyName",CompanyName)
cars.drop("CarName",axis=1,inplace=True)
cars.head()
# Out:
#    car_ID  symboling  CompanyName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
# ...

# %%
cars.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# Replacing all the incorrect words with the correct ones

# %%
cars.CompanyName = cars.CompanyName.str.lower()

# %%
def replace_name(a,b):
    cars.CompanyName.replace(a,b,inplace=True)

# %%
replace_name("maxda","mazda")
replace_name("porcshce","porsche")
replace_name("toyouta","toyota")
replace_name("vokswagen","volkswagen")
replace_name("vw","volkswagen")

# %%
cars.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
cars.loc[cars.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CompanyName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []

# %%
cars.columns
# Out:
# Index(['car_ID', 'symboling', 'CompanyName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
print(cars.columns.shape)
# Out:
# (26,)

# %% [markdown]
# ### Visualizing the data

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Car price distribution plot')
sns.histplot(cars.price)

plt.subplot(1,2,2)
plt.title('Car price spread')
sns.boxplot(y=cars.price)

plt.show()

# %% [markdown]
# Histplot := Shows the price distribution vs count of data points.
#
# Boxplot := Used to show the spread of the datapoints. Ususally used to find outliers.

# %%
#This function is used to help draw inferences on the price distribution 
print(cars.price.describe(percentiles=[0.25,0.5,0.75,0.85,0.90,1]))
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# 85%      18500.000000
# 90%      22563.000000
# 100%     45400.000000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# The 50 percentile mark represents the **median** of that particular column
#
# Inferences:
#
# 1) As we can see from the plots that the dataset is skewed; more number of cars are low-priced.
# 2) The dataset has high variance, as the data points are far spread out from the mean.
# 3) There is quite a bit of difference between the mean and median of the column

# %% [markdown]
# #### Visualising categorical data

# %%
cars.fuelsystem.value_counts()
# Out:
# fuelsystem
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(25,8))

plt.subplot(1,3,1)
plt1 = cars.CompanyName.value_counts().plot(kind='bar')
plt.title('Companies histogram')
plt.xlabel('Company Name')
plt.ylabel('Frequency')

plt.subplot(1,3,2)
plt2 = cars.fueltype.value_counts().plot(kind='bar')
plt.title('Fuel type histogram')
plt.xlabel('Fuel type')
plt.ylabel('Frequency')

plt.subplot(1,3,3)
plt3 = cars.carbody.value_counts().plot(kind='bar')
plt.title('Car body histogram')
plt.xlabel('Car body')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# Inferences:
# 1) Toyota is the most preferred company among the list of companies.
# 2) The gas fuel type is heavily preferred between gas and diesel.
# 3) Out of all the car body types, sedan is the most preferred.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Symboling histogram')
'''
plt1 = cars.symboling.value_counts().plot(kind='bar')
plt1.set_xlabel('Symboling')
plt.ylabel('Count')
''' 
sns.countplot(x=cars.symboling)

plt.subplot(1,2,2)
plt.title('Symboling vs Price')
sns.boxplot(x=cars.symboling,y=cars.price)

plt.show()

# %% [markdown]
# Inferences:
# 1) Cars with symbols '0' and '1' have more number of rows; meaning they are sold more.
# 2) The various differences can be seen in symboling vs price plot.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Engine type historgram')
sns.countplot(x=cars.enginetype)

plt.subplot(1,2,2)
plt.title('Engine type vs Price')
sns.boxplot(x=cars.enginetype,y=cars.price)

plt.show()

# %% [markdown]
# Inferences:
# 1) The engine type ohc is the most used while dohcv is the least used.
# 2) The engine type ohc is the cheapest(alongwith dhcf); whereas ohcv is the costliest.

# %%
#Groups the dataframe according a particular label; and then gets the price label's mean values out of it.
cars.groupby(['enginetype'])['price'].mean()
# Out:
# enginetype
# dohc     18116.416667
# dohcv    31400.500000
# l        14627.583333
# ohc      11574.048426
# ohcf     13738.600000
# ohcv     25098.384615
# rotor    13020.000000
# Name: price, dtype: float64

# %%
df = pd.DataFrame(cars.groupby(['enginetype'])['price'].mean().sort_values(ascending = False))
df.plot.bar(figsize=(8,4))
plt.title('Engine Type vs Average Price')
plt.show()

# %% [markdown]
# Inferences:
# 1) dohcv evidently has the highest average engine price.

# %%
df = pd.DataFrame(cars.groupby(['CompanyName'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Company Name vs Average Price')
plt.show()

df = pd.DataFrame(cars.groupby(['fueltype'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Fuel Type vs Average Price')
plt.show()

df = pd.DataFrame(cars.groupby(['carbody'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Car Type vs Average Price')
plt.show()

# %% [markdown]
# Inferences:
# 1) Jaguar and Buick seem to have the highest average price.
# 2) Diesel cars have a bit higher car price than gas cars
# 3) Hardtop and convertible have higher average prices.

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.title('Door number bar graph')
sns.countplot(x=cars.doornumber)

plt.subplot(1,2,2)
plt.title('Door number vs price')
sns.boxplot(x=cars.doornumber,y=cars.price)

plt.show()

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.title('Aspiration bar graph')
sns.countplot(x=cars.aspiration)

plt.subplot(1,2,2)
plt.title('Aspiration vs price')
sns.boxplot(x=cars.aspiration,y=cars.price)

plt.show()

# %% [markdown]
# Inferences:
# 1) The doornumber variable does not affect the price much.
# 2) The turbo aspiration has higher price range than the std one though it has some price points outsid the whiskers.

# %%
def plot_plots(mystr,pos):
    plt.subplot(4,2,pos)
    plt.title(mystr + ' bar graph')
    sns.countplot(x = cars[mystr])
    plt.subplot(4,2,pos+1)
    plt.title(mystr + ' vs Price')
    sns.boxplot(x=cars[mystr],y=cars['price'])

plt.figure(figsize=(15,20))

plot_plots('enginelocation', 1)
plot_plots('cylindernumber', 3)
plot_plots('fuelsystem', 5)
plot_plots('drivewheel', 7)

plt.show()

# %% [markdown]
# Inferences:
# 1) Almost every car has its engine location at the front.
# 2) Cars having engine at the rear end are more expensive.
# 3) Majority of the cars have 4 cylinders which also have a lowest price range, whereas eight cylinders have a higest price range.
# 4) mpfi and 2bbl are the most commmon fuel systems.
# 5) rwd and fwd are most common wheeldrive categories.

# %% [markdown]
# #### Visualizing numerical data

# %%
cars.head()
# Out:
#    car_ID  symboling  CompanyName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
# ...

# %%
def scatter(x,fig):
    plt.subplot(5,2,fig)
    plt.scatter(cars[x],cars['price'])
    plt.title(x+' vs Price')
    plt.ylabel('Price')
    plt.xlabel(x)

# %%
plt.figure(figsize=(10,20))

scatter('carlength', 1)
scatter('carwidth', 2)
scatter('carheight', 3)
scatter('curbweight', 4)

plt.tight_layout()

# %% [markdown]
# Inferences:
# 1) carwidth, carlength, curbweight have a linear relation with the price of the car(Positive correlation with price).
# 2) carheight does not seem to have a good correlation with price.

# %%
def pairPlot(x,y,z):
    sns.pairplot(cars, x_vars=[x,y,z], y_vars='price', size=4, aspect=1,kind='scatter')
    plt.show()

pairPlot('enginesize', 'boreratio', 'stroke')
pairPlot('compressionratio', 'horsepower', 'peakrpm')
pairPlot('wheelbase', 'citympg', 'highwaympg')
# Out:
# /Users/prithvishah/Desktop/Projects/Car-price-prediction/carPrediction/lib/python3.11/site-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/prithvishah/Desktop/Projects/Car-price-prediction/carPrediction/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/prithvishah/Desktop/Projects/Car-price-prediction/carPrediction/lib/python3.11/site-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/prithvishah/Desktop/Projects/Car-price-prediction/carPrediction/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %% [markdown]
# Inferences:
# 1) Positive correlation with price - enginesize, boreratio, horsepower, wheelbase
# 2) Negative correlation with price - citympg, highwaympg

# %%
#The following line will produce a scatterplot just like the above plots
#sns.scatterplot(x=cars['carlength'],y=cars['price'])
#The below command is the correlation coefficient between two variables
np.corrcoef(cars['carlength'],cars['carwidth'])[0,1]
# Out:
# 0.841118268481845

# %% [markdown]
# #### Deriving new features

# %%
#Converts the dtype of that particular column to the desired dtype 
cars['price'] = cars['price'].astype('int')

# %%
temp = cars.copy()

# %%
temp.head()
table = temp.groupby(['CompanyName'])['price'].mean()

# %%
temp = temp.merge(table.reset_index(), how='left',on='CompanyName')
temp
# Out:
#      car_ID  symboling  CompanyName fueltype aspiration doornumber  \
# 0         1          3  alfa-romero      gas        std        two
# 1         2          3  alfa-romero      gas        std        two
# 2         3          1  alfa-romero      gas        std        two
# 3         4          2         audi      gas        std       four
# 4         5          2         audi      gas        std       four
# ..      ...        ...          ...      ...        ...        ...
# 200     201         -1        volvo      gas        std       four
# 201     202         -1        volvo      gas      turbo       four
# 202     203         -1        volvo      gas        std       four
# 203     204         -1        volvo   diesel      turbo       four
# 204     205         -1        volvo      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0    convertible        rwd          front       88.6      168.8      64.1
# ...

# %%
bins = [0,10000,20000,40000]
cars_bin=['Budget','Medium','Highend']

# %%
cars['carsrange'] = pd.cut(temp['price_y'],bins,right=False,labels=cars_bin)
cars.head()
# Out:
#    car_ID  symboling  CompanyName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
# ...

# %% [markdown]
# #### Bivariate Analysis

# %%
plt.figure(figsize=(25, 6))

df = pd.DataFrame(cars.groupby(['fuelsystem','drivewheel','carsrange'])['price'].mean().unstack(fill_value=0))
df.plot.bar()
plt.title('Car Range vs Average Price')
plt.show()

# %% [markdown]
# List of significant variables after visual analysis:
# - Car Range
# - Engine Type
# - Fuel type
# - Car Body
# - Aspiration
# - Cylinder Number
# - Drivewheel
# - Curbweight
# - Car Length
# - Car width
# - Engine Size
# - Boreratio
# - Horse Power
# - Wheel base

# %%
cars_compressed = cars[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 
                     'carlength','carwidth', 'carsrange']]

# %%
cars_compressed.head()
# Out:
#    price fueltype aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0  13495      gas        std  convertible        rwd       88.6        2548
# 1  16500      gas        std  convertible        rwd       88.6        2548
# 2  16500      gas        std    hatchback        rwd       94.5        2823
# 3  13950      gas        std        sedan        fwd       99.8        2337
# 4  17450      gas        std        sedan        4wd       99.4        2824
#
#   enginetype cylindernumber  enginesize  boreratio  horsepower  carlength  \
# 0       dohc           four         130       3.47         111      168.8
# 1       dohc           four         130       3.47         111      168.8
# 2       ohcv            six         152       2.68         154      171.2
# 3        ohc           four         109       3.19         102      176.6
# 4        ohc           five         136       3.19         115      176.6
#
#    carwidth carsrange
# 0      64.1    Medium
# ...

# %%
sns.pairplot(cars_compressed)
plt.show()
# Out:
# /Users/prithvishah/Desktop/Projects/Car-price-prediction/carPrediction/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
cars_compressed.shape
# Out:
# (205, 15)

# %%
def dummies(x,df):
    temp = pd.get_dummies(df[x], drop_first = True)
    df = pd.concat([df, temp], axis = 1)
    df.drop([x], axis = 1, inplace = True)
    return df

# %%
cars_compressed = dummies('fueltype',cars_compressed)
cars_compressed = dummies('aspiration',cars_compressed)
cars_compressed = dummies('carbody',cars_compressed)
cars_compressed = dummies('drivewheel',cars_compressed)
cars_compressed = dummies('enginetype',cars_compressed)
cars_compressed = dummies('cylindernumber',cars_compressed)
cars_compressed = dummies('carsrange',cars_compressed)

# %%
cars_compressed.head()
# Out:
#    price  wheelbase  curbweight  enginesize  boreratio  horsepower  carlength  \
# 0  13495       88.6        2548         130       3.47         111      168.8
# 1  16500       88.6        2548         130       3.47         111      168.8
# 2  16500       94.5        2823         152       2.68         154      171.2
# 3  13950       99.8        2337         109       3.19         102      176.6
# 4  17450       99.4        2824         136       3.19         115      176.6
#
#    carwidth   gas  turbo  hardtop  hatchback  sedan  wagon    fwd    rwd  \
# 0      64.1  True  False    False      False  False  False  False   True
# 1      64.1  True  False    False      False  False  False  False   True
# 2      65.5  True  False    False       True  False  False  False   True
# 3      66.2  True  False    False      False   True  False   True  False
# 4      66.4  True  False    False      False   True  False  False  False
#
# ...

# %%
cars_compressed.shape
# Out:
# (205, 30)

# %% [markdown]
# Train-Test-Split and Feature Scaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
np.random.seed(0)
df_train, df_test = train_test_split(cars_compressed, random_state=42, test_size=0.2)

# %%
df_train.to_csv('Data/train.csv',index=False)
df_test.to_csv('Data/test.csv',index=False)

# %%
scaler = MinMaxScaler()
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','carlength','carwidth','price']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#         price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 66   0.328335   0.631034    0.392078    0.250000   0.635714    0.084746
# 111  0.259719   0.734483    0.558968    0.195312   0.657143    0.182203
# 153  0.044685   0.313793    0.205162    0.085938   0.364286    0.042373
# 96   0.059108   0.272414    0.067646    0.105469   0.435714    0.072034
# 38   0.098729   0.341379    0.209168    0.156250   0.435714    0.144068
#
#      carlength  carwidth    gas  turbo  hardtop  hatchback  sedan  wagon  \
# 66    0.524138  0.409524  False  False    False      False   True  False
# 111   0.725862  0.628571   True  False    False      False   True  False
# 153   0.432759  0.171429   True  False    False      False  False   True
# 96    0.356897  0.190476   True  False    False      False   True  False
# 38    0.394828  0.323810   True  False    False       True  False  False
#
#        fwd    rwd  dohcv      l    ohc   ohcf   ohcv  rotor   five  four  \
# ...

# %%
columns = list(df_train.columns)

# %%
#Converts every boolean in this particular dataframe to integer
for column in columns[8:]:
    df_train[column] = df_train[column].astype(int)

# %%
df_train.describe()
# Out:
#             price   wheelbase  curbweight  enginesize   boreratio  horsepower  \
# count  164.000000  164.000000  164.000000  164.000000  164.000000  164.000000
# mean     0.201217    0.418230    0.328188    0.220370    0.557753    0.223310
# std      0.192299    0.205824    0.227831    0.158082    0.192690    0.170458
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.064241    0.272414    0.153093    0.109375    0.435714    0.082627
# 50%      0.137245    0.350000    0.268580    0.193359    0.550000    0.182203
# 75%      0.283197    0.534483    0.498554    0.277344    0.714286    0.271186
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         carlength    carwidth         gas       turbo     hardtop   hatchback  \
# count  164.000000  164.000000  164.000000  164.000000  164.000000  164.000000
# mean     0.509094    0.392625    0.908537    0.176829    0.030488    0.341463
# ...

# %%
#Checks if there are any null values present in the entire dataframe
df_train.isnull().any().sum()
# Out:
# 0

# %%
df_train.head()
# Out:
#         price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 66   0.328335   0.631034    0.392078    0.250000   0.635714    0.084746
# 111  0.259719   0.734483    0.558968    0.195312   0.657143    0.182203
# 153  0.044685   0.313793    0.205162    0.085938   0.364286    0.042373
# 96   0.059108   0.272414    0.067646    0.105469   0.435714    0.072034
# 38   0.098729   0.341379    0.209168    0.156250   0.435714    0.144068
#
#      carlength  carwidth  gas  turbo  hardtop  hatchback  sedan  wagon  fwd  \
# 66    0.524138  0.409524    0      0        0          0      1      0    0
# 111   0.725862  0.628571    1      0        0          0      1      0    0
# 153   0.432759  0.171429    1      0        0          0      0      1    1
# 96    0.356897  0.190476    1      0        0          0      1      0    1
# 38    0.394828  0.323810    1      0        0          1      0      0    1
#
# ...

# %%
#Corelation using heatmap
plt.figure(figsize=(30,25))
sns.heatmap(df_train.corr(), annot=True,center=1)
# Out:
# <Axes: >

# %% [markdown]
# Highly correlated variables are - curbweight, enginesize, horsepower, carwidth and highend

# %% [markdown]
# Here the EDA and preprocessing ends
